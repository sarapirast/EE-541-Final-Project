# %%
import pandas as pd
import random
import re
from collections import Counter
import numpy as np

train= pd.read_csv("data/atis_train.csv")
val= pd.read_csv("data/atis_val.csv")
test= pd.read_csv("data/atis_test.csv")

print("Train intents:\n",train["intent"].value_counts(),"\n")
print("Val intents:\n",val["intent"].value_counts(),"\n")
print("Test intents:\n",test["intent"].value_counts(),"\n")
# Out:
# Train intents:
#  intent
# flight            2932
# airfare            339
# ground_service     204
# airline            125
# abbreviation       118
# aircraft            65
# flight_time         43
# quantity            41
# flight+airfare      17
# distance            16
# airport             16
# city                15
# ground_fare         14
# capacity            13
# flight_no           10
# restriction          5
# meal                 5
# Name: count, dtype: int64
#
# Val intents:
#  intent
# flight            734
# airfare            85
# ground_service     51
# airline            32
# abbreviation       29
# aircraft           16
# flight_time        11
# quantity           10
# ground_fare         4
# city                4
# distance            4
# airport             4
# flight+airfare      4
# capacity            3
# flight_no           2
# restriction         1
# meal                1
# Name: count, dtype: int64
#
# Test intents:
#  intent
# flight            632
# airfare            48
# airline            38
# ground_service     36
# abbreviation       33
# capacity           21
# airport            18
# flight+airfare     13
# distance           10
# aircraft            9
# flight_no           8
# ground_fare         7
# city                6
# meal                6
# flight_time         3
# quantity            3
# Name: count, dtype: int64

# %% [markdown]
# Test missing an intent but that is expected

# %%
months = ["january","february","march","april","may","june","july","august","september","october","november","december"]
def tokenize(text):
  text= text.lower().strip()
  for m in months:
    text = re.sub(rf"\b{m}\b", "<month>", text)
  text= re.sub(r"\d+", "<num>", text) #nums not needed
  text = re.sub(r"(\w)'(\w)", r"\1\2", text)
  text= re.sub(r"[^\w\s<>]", "", text)
  return text.split()

def vocab():
  tokens= [token for sent in train["text"] for token in tokenize(sent)]
  counter= Counter(tokens)
  min=1
  pad_token= "<pad>"
  unk_token= "<unk>"

  word_idx={
      pad_token: 0,
      unk_token: 1,
  }
  for word, count in sorted(counter.items()):
    if count >= min and word not in word_idx:
      word_idx[word] = len(word_idx)
  idx_word= {i: w for w, i in word_idx.items()}
  print(idx_word)

vocab()
# Out:
# {0: '<pad>', 1: '<unk>', 2: '<month>', 3: '<num>', 4: '<num>s', 5: 'a', 6: 'aa', 7: 'abbreviation', 8: 'abbreviations', 9: 'able', 10: 'about', 11: 'ac', 12: 'actually', 13: 'advertises', 14: 'after', 15: 'afternoon', 16: 'afternoons', 17: 'afterwards', 18: 'again', 19: 'air', 20: 'aircraft', 21: 'airfare', 22: 'airfares', 23: 'airline', 24: 'airlines', 25: 'airplane', 26: 'airplanes', 27: 'airport', 28: 'airports', 29: 'alaska', 30: 'all', 31: 'along', 32: 'also', 33: 'am', 34: 'america', 35: 'american', 36: 'amount', 37: 'an', 38: 'and', 39: 'angeles', 40: 'another', 41: 'any', 42: 'anything', 43: 'anywhere', 44: 'ap', 45: 'ap<num>', 46: 'approximately', 47: 'are', 48: 'area', 49: 'arizona', 50: 'around', 51: 'arrange', 52: 'arrangements', 53: 'arrival', 54: 'arrivals', 55: 'arrive', 56: 'arrives', 57: 'arriving', 58: 'as', 59: 'at', 60: 'atl', 61: 'atlanta', 62: 'available', 63: 'b', 64: 'back', 65: 'baltimore', 66: 'bay', 67: 'be', 68: 'beach', 69: 'before', 70: 'beginning', 71: 'begins', 72: 'being', 73: 'belong', 74: 'besides', 75: 'between', 76: 'boeing', 77: 'book', 78: 'booking', 79: 'boston', 80: 'both', 81: 'bound', 82: 'breakfast', 83: 'bring', 84: 'bur', 85: 'burbank', 86: 'business', 87: 'but', 88: 'buy', 89: 'bwi', 90: 'by', 91: 'c', 92: 'california', 93: 'calling', 94: 'can', 95: 'canada', 96: 'canadian', 97: 'capacities', 98: 'capacity', 99: 'car', 100: 'carolina', 101: 'carried', 102: 'carries', 103: 'cars', 104: 'charlotte', 105: 'cheap', 106: 'cheapest', 107: 'chicago', 108: 'choices', 109: 'cincinnati', 110: 'cities', 111: 'city', 112: 'class', 113: 'classes', 114: 'cleveland', 115: 'close', 116: 'closest', 117: 'co', 118: 'coach', 119: 'code', 120: 'codes', 121: 'colorado', 122: 'columbus', 123: 'come', 124: 'coming', 125: 'companies', 126: 'concerning', 127: 'connect', 128: 'connecting', 129: 'connection', 130: 'connections', 131: 'connects', 132: 'continental', 133: 'continuing', 134: 'cost', 135: 'costs', 136: 'could', 137: 'county', 138: 'cover', 139: 'cp', 140: 'currently', 141: 'd', 142: 'd<num>', 143: 'daily', 144: 'dallas', 145: 'database', 146: 'day', 147: 'days', 148: 'dc', 149: 'dc<num>', 150: 'define', 151: 'delta', 152: 'denver', 153: 'depart', 154: 'departing', 155: 'departs', 156: 'departure', 157: 'departures', 158: 'describe', 159: 'designate', 160: 'destination', 161: 'detroit', 162: 'dfw', 163: 'diego', 164: 'difference', 165: 'different', 166: 'dinner', 167: 'dinnertime', 168: 'direct', 169: 'directly', 170: 'discount', 171: 'display', 172: 'distance', 173: 'dl', 174: 'do', 175: 'does', 176: 'doesn', 177: 'dollars', 178: 'downtown', 179: 'dulles', 180: 'during', 181: 'ea', 182: 'each', 183: 'earlier', 184: 'earliest', 185: 'early', 186: 'eastern', 187: 'economic', 188: 'economy', 189: 'eight', 190: 'eighteenth', 191: 'eighth', 192: 'either', 193: 'eleven', 194: 'eleventh', 195: 'else', 196: 'enroute', 197: 'equal', 198: 'equipment', 199: 'evening', 200: 'everywhere', 201: 'ewr', 202: 'expensive', 203: 'explain', 204: 'express', 205: 'eye', 206: 'f', 207: 'f<num>', 208: 'far', 209: 'fare', 210: 'fares', 211: 'ff', 212: 'field', 213: 'fifteenth', 214: 'fifth', 215: 'final', 216: 'find', 217: 'fine', 218: 'first', 219: 'fit', 220: 'flies', 221: 'flight', 222: 'flights', 223: 'florida', 224: 'fly', 225: 'flying', 226: 'fn', 227: 'following', 228: 'for', 229: 'fort', 230: 'four', 231: 'fourteenth', 232: 'fourth', 233: 'francisco', 234: 'friday', 235: 'friends', 236: 'from', 237: 'general', 238: 'georgia', 239: 'get', 240: 'gets', 241: 'give', 242: 'go', 243: 'goes', 244: 'going', 245: 'got', 246: 'great', 247: 'greatest', 248: 'ground', 249: 'grounds', 250: 'guardia', 251: 'h', 252: 'hare', 253: 'has', 254: 'have', 255: 'having', 256: 'heading', 257: 'hello', 258: 'help', 259: 'here', 260: 'hi', 261: 'highest', 262: 'hold', 263: 'home', 264: 'hopefully', 265: 'hours', 266: 'houston', 267: 'how', 268: 'hp', 269: 'i', 270: 'iah', 271: 'if', 272: 'in', 273: 'include', 274: 'includes', 275: 'in ...

# %%
synonyms= {
    "airfare": ["airfares"],
    "airfares":["airfare"],
    "airline": ["airlines"],
    "airlines": ["airline"],
    "arrive": ["arrives", "arriving"],
    "arrives": ["arrive"],
    "arriving": ["arrive"],
    "depart": ["departing","departs"],
    "departing": ["depart"],
    "departs": ["depart"],
    "flight": ["flights"],
    "flights": ["flight"],
    "trip": ["trips"],
    "trips": ["trip"],
    "fare": ["fares"],
    "fares": ["fare"],
    "price": ["prices"],
    "prices": ["price"],
    "meal": ["meals"],
    "meals": ["meal"],
  }

# %%
def augment_tokens(tokens,ins_,del_,rep_):
  #augment based on the probs
  augmented_tokens=[]
  for tok in tokens:
    if random.random()<del_ and len(tokens)>3: #no delete for short sent
      continue
    if tok in synonyms and random.random()<rep_:
      augmented_tokens.append(random.choice(synonyms[tok]))
    else:
      augmented_tokens.append(tok)
  for i in range(len(augmented_tokens)):
    if random.random()<ins_:
      ins= random.choice(["show","list","view"])
      augmented_tokens.insert(i, ins)
  return augmented_tokens

def augment_text(text,ins_,del_,rep_):
  tokens= tokenize(text)
  augmented_tokens= augment_tokens(tokens,ins_,del_,rep_)
  return " ".join(augmented_tokens)

# %%
def augmentation(df,frac,ins_,del_,rep_):
  random.seed(42)
  aug_row=[]
  n= int(len(df)* frac)
  sampled = df.sample(n,random_state=42)
  for index, row in sampled.iterrows():
    original_text= row["text"]
    new_text = augment_text(original_text,ins_,del_,rep_)
    aug_row.append({
        "text": new_text,
        "intent": row["intent"],
        "label": row["label"]
    })
  aug_df= pd.DataFrame(aug_row)
  full= pd.concat([df,aug_df])
  return full

# %%
aug_train= augmentation(train,frac=1,ins_=0.05,del_=0.05,rep_=0.05)
print("Original train size:",len(train))
print("Augmented train size:",len(aug_train))
# Out:
# Original train size: 3978
# Augmented train size: 7956
